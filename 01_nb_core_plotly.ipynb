# %% [markdown]
# <a href="https://colab.research.google.com/github/eangamarcas/oriented_drillcore/blob/main/01_nb_core_plotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Usar funciones definidas en Notebook (.ipynb)
# %cd /content/drive/MyDrive/Colab Notebooks/oriented_drillcore
# %run '00 fn core_go.ipynb'
# Out:
# /content/drive/MyDrive/Colab Notebooks/oriented_drillcore

# %% [markdown]
# # Oriented Core with Plotly

# %%
center = (100,100,100)
radius, height = 2, 7

trd_hole, plg_hole = 305, 45
alpha, beta, gamma, betaL = 15, 50, 300, 70

stk, dip = 70, 70
trd, plg = 80, 27

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig = go.Figure(data=(
                      cylinder3D (center,radius,-height,trd_hole,plg_hole,(0,255,0),.1) +         # core / drill hole ↑
                      cylinder3D (center,radius,height,trd_hole,plg_hole,(0,255,0),.2) +          # core / drill hole ↓

                      plane3D (center,radius,stk,dip,(255,128,0),.8) +                            # PLANE v1
                      plane3D_symb (center,radius,stk,dip,(0,0,0)) +                              # PLANE / labeling strike n' dip
                      #disk3D (center,radius,stk,dip,(255,128,0),1)  +                             # PLANE v2
                      #line3D (center,radius,stk,dip,1,(0,0,0)) +                                  # PLANE / polo to plane
                      line3D (center,radius,trd,plg,0,(0,152,70)) +                               # LINE  / labeling trend n' plunge

                      core_axis (center,height,trd_hole,plg_hole,(155,155,155)) +                 # L CA   → Core Axis
                      bottom_hole (center,radius,height,trd_hole,plg_hole,(0,0,255)) +            # L BOH  → Bottom of hole line
                      long_axis (center,radius,height,trd_hole,plg_hole,beta,(0,0,0)) +           # L E E' → Lower-Upper end of Long axis of Intersection elipse

                      angle_alpha (center,radius,trd_hole,plg_hole,stk,dip,alpha,1,(255,0,0)) +   # ∡ α alpha
                      angle_beta(center,radius,height,trd_hole,plg_hole,beta,(0,255,0)) +         # ∡ β  beta
                      angle_betaL (center,radius,height,trd_hole,plg_hole,betaL,(0,255,0)) +      # ∡ βL betaL
                      angle_gamma (center,radius,stk,dip,gamma,(0,255,0))                         # ∡ γ  gamma
                      ))

north = north3D((106,94,100), 2.5)                                                                # symbol north
fig.add_traces(north)

# Configuración del layout
fig.update_layout(layout_core ())
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="786d033b-ef11-4b4b-9382-1158d2ce07ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("786d033b-ef11-4b4b-9382-1158d2ce07ba")) {                    Plotly.newPlot(                        "786d033b-ef11-4b4b-9382-1158d2ce07ba",                        [{"colorscale":[[0,"rgb(0, 255, 0)"],[1,"rgb(0, 255, 0)"]],"opacity":0.1,"showscale":false,"x":[[101.1471528727021,101.07136946696008,100.99127203450777,100.90718309943581,100.81944125820704,100.72839981624816,100.63442536531342,100.53789630734903,100.4392013308021,100.33873784550941,100.23691038246827,100.13412896493297,100.03080745739587,99.92736189910113,99.82420882880155,99.72176360750397,99.6204387459572,99.52064224361666,99.42277594577475,99.32723392547157,99.23440089670193,99.