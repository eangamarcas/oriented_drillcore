# %% [markdown]
# # Install Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# %cd /content/drive/MyDrive/resources
# %run 'imp_fonts.ipynb'
# %cd /content/drive/MyDrive/projects/oriented_drillcore
# %run '00 fn core_mpl.ipynb'

# %% [markdown]
# # Work

# %%
# Data:
tr, pl, α, β, γ, βL = 145, 72, 40, 215, 24, 69.70854 #11

# %%
result_a = ornt_core (tr, pl, α, β, 'a')
result_b = ornt_core (tr, pl, α, β, 'b', γ)
result_c = ornt_core (tr, pl, α, β, 'c', βL)

print('dip      ddr       stk       plg      trd       rke')
print(", ".join(f"{x:.4f}" for x in result_a))
print(", ".join(f"{x:.4f}" for x in result_b))
print(", ".join(f"{x:.4f}" for x in result_c))
# Out:
# dip      ddr       stk       plg      trd       rke
# 36.3668, 192.8177, 102.8177
# 36.3668, 192.8177, 102.8177, 36.0871, 201.0036, 96.6073
# 36.3668, 192.8177, 102.8177, 36.0871, 201.0036, 96.6073

# %%
plot_mtd1(tr, pl, α, β, save=True)

# %%
plot_mtd2 (tr, pl, α, β, γ, save=True)

# %%
plot_mtd3 (tr, pl, α, β, βL, save=True)

# %%
plot_mtd4 (tr, pl, α, β, gamma=γ, betaL=βL, option='C', save=True)

# %%
#Rename to save to drive
# %cd "/content/drive/MyDrive/projects/oriented_drillcore"

# !mv 'method_αβ.png' '02.1 method αβ.png'
# !mv 'method_γ.png'  '02.2 method γ.png'
# !mv 'method_βL.png' '02.3 method βL.png'
# !mv 'methods.png'   '02.4 methods.png'
# Out:
# /content/drive/MyDrive/projects/oriented_drillcore
